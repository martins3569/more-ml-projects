# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
    with open(filename, "r") as file:
        lines = file.readlines()
        words = []
        
        for line in lines:
            words += re.findall(r'\w+', line.lower())
            
        return words

# %%
words = read_corpus("./big.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 1115760 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 32208 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["love"])
# Out:
# 484

# %%
word_counts = Counter(words)
print(word_counts["the"])
# Out:
# 79814

# %%
word_counts = Counter(words)
print(word_counts["sherlock"])
# Out:
# 101

# %%
total_word_counts = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_counts for word in word_counts.keys()}

# %%
print(word_probas["sherlock"])
# Out:
# 9.052125905212591e-05

# %%
print(word_probas["the"])
# Out:
# 0.07153330465333047

# %%
def split(word):
    return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
def delete(word):
    return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
def swap(word):
    return [l + r[1] + r[0] + r[2:] for l,r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
def replace(word):
    letters = string.ascii_lowercase
    return [l + c + r[1:] for l,r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
    letters = string.ascii_lowercase
    return [l + c + r for l,r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %%
def level_one_edits(word):
    return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(level_one_edits("trash"))
# Out:
# {'trayh', 'traash', 'ptrash', 'trqash', 'srash', 'arash', 'btrash', 'tnrash', 'travh', 'trasf', 'truash', 'otrash', 'rtrash', 'ttrash', 'turash', 'trsash', 'trzash', 'wtrash', 'trasq', 'trasph', 'trazh', 'tirash', 'thash', 'teash', 'trach', 'tranh', 'qtrash', 'tfrash', 'trpsh', 'trafsh', 'traskh', 'traszh', 'trashh', 'trasch', 'txash', 'transh', 'tratsh', 'trase', 'tresh', 'trasz', 'tcrash', 'tmrash', 'strash', 'trarsh', 'trasih', 'traqsh', 'traswh', 'krash', 'yrash', 'frash', 'trjsh', 'trrsh', 'trafh', 'tralh', 'utrash', 'traah', 'trmsh', 'trtsh', 'trabsh', 'tryash', 'trasuh', 'trass', 'urash', 'trbsh', 'trasb', 'trasn', 'tsash', 'trosh', 'tralsh', 'tlash', 'trahs', 'trakh', 'tfash', 'trcsh', 'tragsh', 'zrash', 'trauh', 'traih', 'tash', 'tnash', 'traso', 'trath', 'brash', 'trasp', 'traxh', 'hrash', 'ktrash', 'twash', 'trmash', 'trasc', 'trash', 'trashz', 'rtash', 'trasj', 'tjrash', 'tuash', 'crash', 'trasht', 'jtrash', 'trabh', 'trast', 'tarsh', 'txrash', 'traysh', 'trashi', 'tbash', 'irash', 'traxsh', 'tgrash', 'trsah', 'tiash', 'atrash', 'grash', 'trasx', 'trgash', 'drash', 'nrash', 'ctrash', 'tvrash', 'troash', 'trahsh', 'trassh', 'trashy', 'erash', 'tradsh', 'trssh', 'etrash', 'trashf', 'traph', 'trashw', 'traqh', 'trush', 'treash', 'trtash', 'itrash', 'tyrash', 'trlsh', 'trasvh', 'trasyh', 'trasi', 'trashb', 'trashg', 'tgash', 'trfash', 'trasth', 'trasqh', 'travsh', 'traslh', 'trqsh', 'trasdh', 'terash', 'tzrash', 'trasmh', 'trashl', 'trazsh', 'trasy', 'ftrash', 'trasg', 'trxash', 'trashc', 'trasbh', 'qrash', 'wrash', 'trajsh', 'traish', 'trasd', 'jrash', 'tqrash', 'htrash', 'tkrash', 'trbash', 'trdash', 'trasah', 'trashd', 'vrash', 'trlash', 'trish', 'trxsh', 'trnash', 'trasr', 'tbrash', 'trfsh', 'twrash', 'tsrash', 'trasrh', 'trasha', 'trashq', 'trapsh', 'trnsh', 'tramh', 'ytrash', 'trashr', 'thrash', 'tcash', 'tqash', 'trgsh', 'trasfh', 'trasjh', 'tracsh', 'trashn', 'trasl', 'trysh', 'vtrash', 'traeh', 'trashm', 'tlrash', 'trawsh', 'rrash', 'trpash', 'tradh', 'ntrash', 'trjash', 'traosh', 'trashe', 'xtrash', 'rash', 'trhsh', 'trasxh', 'trashj', 'traush', 'prash', 'trasho', 'trashx', 'mrash', 'mtrash', 'trajh', 'trashp', 'xrash', 'trvsh', 'trasgh', 'trvash', 'trashu', 'trrash', 'toash', 'ttash', 'tdash', 'tras', 'trasv', 'traesh', 'taash', 'trksh', 'trhash', 'trcash', 'trashv', 'trashs', 'torash', 'lrash', 'trdsh', 'trashk', 'tarash', 'ztrash', 'trzsh', 'trahh', 'tjash', 'trask', 'trasnh', 'trarh', 'trkash', 'ltrash', 'tprash', 'orash', 'gtrash', 'trasu', 'traksh', 'trah', 'tkash', 'tragh', 'traseh', 'tramsh', 'trasoh', 'trasm', 'tdrash', 'trwsh', 'trawh', 'trsh', 'dtrash', 'tmash', 'trwash', 'tpash', 'tyash', 'tvash', 'triash', 'traoh', 'tzash', 'trasw', 'trasa'}

# %%
def level_two_edits(word):
    return set(e2 for e1 in level_one_edits(word) for e2 in level_one_edits(e1))

# %%
print(level_two_edits("trash"))
# Out:
# {'trxashk', 'trvsj', 'tlrasq', 'tsrashi', 'turasah', 'tuasah', 'wtfrash', 'graso', 'traphz', 'trvasu', 'mtrasth', 'trbasrh', 'ltbash', 'trscsh', 'twrasqh', 'tryass', 'trbach', 'ptsash', 'trqaeh', 'trasahc', 'trcasnh', 'patrash', 'ctrasb', 'tsaah', 'tramshh', 'vteash', 'crqsh', 'trgshq', 'ttzash', 'tqamsh', 'tratnsh', 'taasa', 'utraah', 'tkrashx', 'atrpsh', 'tarasth', 'tarasxh', 'trabsq', 'trdvsh', 'zfrash', 'otrdsh', 'traae', 'hwash', 'txrzash', 'troamsh', 'trwarh', 'traspm', 'thxsh', 'mrashc', 'strasha', 'jrashh', 'traslf', 'sgrash', 'eriash', 'lrasl', 'brashp', 'trwashp', 'etrashi', 'wrpsh', 'hrasc', 'tmraseh', 'traxjsh', 'urush', 'trosm', 'trazshu', 'traphn', 'trkagh', 'sitrash', 'trmagh', 'tralsw', 'tranhq', 'wtrasnh', 'traxsa', 'xrasz', 'trarc', 'wbrash', 'hraxsh', 'turasph', 'tradhj', 'eyash', 'trzjh', 'rtqsh', 'trasinh', 'trqcash', 'fras', 'trrarh', 'tractsh', 'tpsah', 'grasx', 'wtdash', 'trlkh', 'mktrash', 'terasc', 'gpash', 'trjash', 'trashnf', 'qyash', 'tsasnh', 'tcasn', 'qrrash', 'teralsh', 'tqravh', 'tratm', 'traslhs', 'trashis', 'transhr', 'trasihv', 'trasdp', 'tyysh', 'otrasl', 'trobash', 'srahsh', 'traskho', 'tragsl', 'trxasdh', 'nrah', 'teraish', 'tkrasm', 'tragmsh', 'tranjh', 'trimash', 'brasbh', 'atreash', 'brashq', 'vfrash', 'trdasha', 'gtrmash', 'tracshy', 'terashz', 'ctaash', 'traehg', 'btrssh', 'trxjh', 'trasxhf', 'trayshs', 'dtraah', 'tzasj', 'trasso', 'tdassh', 'trazsk', 'traqd', 'tmasfh', 'ntrassh', 'trpashs', 'tquash', 'htrasx', 'rtasht', 'trsadh', 'trafush', 'nrasha', 'yrash', 'ltrasdh', 'trkwh', 'trxsdh', 'btryash', 'ftraso', 'ettrash', 'ttsh', 'trassw', 'thraxsh', 'trhsch', 'bqrash', 'trafdh', 'trashth', 'traxho', 'tashe', 'trpkh', 'ltrah', 'tjashk', 'tjrasht', 'detrash', 'knrash', 'tcraush', 'trasfoh', 'trathh', 'trcbh', 'trapq', 'hraqh', 'trasnwh', 'tradshf', 'trvsd', 'trace', 'wrasah', 'yutrash', 'tarph', 'trsxah', 'trdmh', 'trarhf', 'trawsk', 'trasxhk', 'dtrjsh', 'trasynh', 'trbasxh', 'rraosh', 'trahshq', 'toraseh', 'trcsb', 'toaash', 'twrsh', 'tmxsh', 'ttrafh', 'vtrrsh', 'tcrasuh', 'txavsh', 'ltresh', 'mrasc', 'trasznh', 'wtrashx', 'wftrash', 'xtorash', 'tryxh', 'tredash', 'krasvh', 'irasth', 'trahshk', 'trpsb', 'trwaah', 'jtmash', 'trhasl', 'traisfh', 'trajxsh', 'trauqsh', 'oraseh', 'travshc', 'trrss', 'trxcsh', 'gtrasb', 'trvwash', 'orarsh', 'vvash', 'graqsh', 'trnashk', 'ptrasxh', 'twaszh', 'hrush', 'lryash', 'tradsdh', 'trpsp', 'grasfh', 'traexh', 'trapsd', 'tratsbh', 'ntrfash', 'traqsrh', 'trafshv', 'trsmah', 'wrashk', 'trrashs', 'trosmh', 'ihrash', 'ugash', 'toaesh', 'tgrasph', 'tsrass', 'htrasy', 'tirasoh', 'tracxsh', 'dresh', 'trasbrh', 'tuzrash', 'utrqash', 'tmrasph', 'trqaso', 'toaskh', 'tlrasnh', 'erarh', 'trdshj', 'trreh', 'trasafh', 'trasmhv', 'trabpsh', 'trhsbh', 'tyrasb', 'btresh', 'triasrh', 'tdaoh', 'xtrasgh', 'trianh', 'trzsa', 'txashg', 'tarahh', 'traskhk', 'trapshe', 'tzrashx', 'truaxsh', 'tnrasah', 'tirasf', 'trlasz', 'tlrath', 'tvrtash', 'toasuh', 'tpjash', 'tpwsh', 'tsxash', 'otoash', 'tsrasj', 'traua', 'trrssh', 'trushk', 'tracph', 'taase', 'tnrawsh', 'tyrdash', 'ttaseh', 'trrasah', 'tdrdsh', 'trxagh', 'ztrosh', 'trcsh', 'thmash', 'ktrasi', 'wraash', 'trashvf', 'htrast', 'otrish', 'vrsah', 'trabhb', 'traplsh', 'xtrashq', 'turashz', 'trlasnh', 'trssm', 'trashps', 'trzath', 'tyasph', 'trnajh', 'jzash', 'tjasjh', 'btrasmh', 'traseth', 'xrzsh', 'atirash', 'trgarh', 'trashlo', 'trajst', 'trysf', 'trasdsh', 'trayht', 'teresh', 'tarasj', 'trljsh', 'harsh', 'tyashs', 'jtrjsh', 'trxasn', 'qtrasd', 'traashs', 'tasz', 'trasgj', 'arasz', 'twrabsh', 'torlash', 'trfarsh', 'ztrtsh', 'tradhsh', 'tvraesh', 'tlratsh', 'tdasjh', 'strasd', 'trxashv', 'trarsfh', 'torasq', 'trsse', 'araysh', 'tnasph', 'xraoh', 'tcradsh', 'tqash', 'traxhsh', 'tqrashk', 'rtraqh', 'tralish', 'ptrasrh', 'ntrtsh', 'twrawsh', 'gransh', 'xrarsh', 'tdvrash', 'trqashk', 'trmacsh', 'trahslh', 'utrhash', 'trathn', 'tlravsh', 'htrach', 'trjasb', 'tdrasjh', 'yyrash', 'atrdsh', 'traishx', 'trapshb', 'trasuhz', 'xtralsh',  ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
    if word in vocabulary:
        print(f"{word} is already correctly spelt")
        return
    suggestions = level_one_edits(word) or level_two_edits(word) or [word]
    best_guesses = [w for w in suggestions if w in vocabulary]
    return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
guesses = correct_spelling(word, vocabs, word_probas)

print(guesses)
# Out:
# [('famine', 2.688750268875027e-06), ('family', 0.00018821251882125188)]

# %%
word = "jsus"
guesses = correct_spelling(word, vocabs, word_probas)

print(guesses)
# Out:
# [('jesus', 9.8587509858751e-06)]

# %%
word = "aflica"
guesses = correct_spelling(word, vocabs, word_probas)

print(guesses)
# Out:
# [('africa', 2.1510002151000216e-05)]

# %%
word = "foad"
guesses = correct_spelling(word, vocabs, word_probas)

print(guesses)
# Out:
# [('ford', 6.2737506273750625e-06), ('foal', 8.96250089625009e-07), ('foam', 3.585000358500036e-06), ('road', 0.00023123252312325231), ('fold', 2.0613752061375205e-05), ('fad', 8.96250089625009e-07), ('fond', 5.467125546712555e-05), ('load', 7.170000717000072e-06), ('food', 6.721875672187568e-05)]

# %%
jovian.commit()
# Out:
# [jovian] Committed successfully! https://jovian.ai/martins3569/spell-checker
# 'https://jovian.ai/martins3569/spell-checker'

# %%
class SpellChecker(object):
    
    def __init__(self, corpus_file_path):
        with open(corpus_file_path, "r") as file:
            lines = file.readlines()
            words = []
            for line in lines:
                words += re.findall(r'\w+', line.lower())
            
        self.vocabs = set(words)
        self.word_counts = Counter(words)
        total_words = float(sum(self.word_counts.values()))
        self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}
        
    def _level_one_edits(self, word):
        letters = string.ascii_lowercase
        splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes = [l + r[1:] for l,r in splits if r]
        swaps = [l + r[1] + r[0] + r[2:] for l,r in splits if len(r)>1]
        replaces = [l + c + r[1:] for l,r in splits if r for c in letters]
        inserts = [l + c + r for l,r in splits for c in letters]
        
        return set(deletes + swaps + replaces + inserts)
    
    def _level_two_edits(self, word):
        return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edit(e1))
    
    def check(self, word):
        candidate = self._level_one_edits(word) or self._level_two_edits(word) or [word]
        valid_candidates = [w for w in candidate if w in self.vocabs]
        return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("./big.txt")

# %%
mispelled_word = "sentense"
print(checker.check(mispelled_word))
# Out:
# [('sentence', 2.3302502330250233e-05)]

# %%
mispelled_word = "sentenee"
print(checker.check(mispelled_word))
# Out:
# [('sentence', 2.3302502330250233e-05)]

# %%
mispelled_word = "artiicial"
print(checker.check(mispelled_word))
# Out:
# [('artificial', 3.316125331612533e-05)]

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "martins3569/spell-checker" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/martins3569/spell-checker
# 'https://jovian.ai/martins3569/spell-checker'
